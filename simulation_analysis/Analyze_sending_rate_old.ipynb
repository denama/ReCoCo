# %%
import pandas as pd
import numpy as np
from plot_cdf import plot_cdf, plot_cdf_multiple
import matplotlib.pyplot as plt
import json
import os
import glob

# %%
i=3
df = pd.DataFrame(l_rate[i]["list_of_packets"])
df
# Out:
#       arrival_time_ms  header_length  padding_length  payload_size  \
# 0                 150             24               0          1394
# 1                 164             24               0          1394
# 2                 179             24               0          1394
# 3                 194             24               0          1394
# 4                 208             24               0          1395
# ...               ...            ...             ...           ...
# 2501            57514             24               0           861
# 2502            57541             24               0           748
# 2503            57547             24               0           749
# 2504            57576             24               0           748
# 2505            57582             24               0           749
#
#       payload_type  send_time_ms  sequence_number      ssrc first_packet  \
# 0              126            35                1  12648429         True
# 1              126            40                2  12648429         None
# 2              126            50                3  12648429         None
# 3              126            60                4  12648429         None
# 4              126            70                5  12648429         True
# ...            ...           ...              ...       ...          ...
# 2501           126         57404             2502  12648429         None
# 2502           126         57434             2503  12648429         None
# 2503           126         57439             2504  12648429         None
# 2504           126         57469             2505  12648429         None
# 2505           126         57474             2506  12648429         None
#
#      last_packet
# 0           None
# 1           None
# 2           None
# 3           True
# 4           None
# ...          ...
# 2501        None
# 2502        None
# 2503        None
# 2504        None
# 2505        True
#
# [2506 rows x 10 columns]

# %%
df[["arrival_time_ms", "send_time_ms"]].plot()

# %%
for i in range(0,len(l_rate)-1):
    average_delay = l_rate[i]["delay"]
    df = pd.DataFrame(l_rate[i]["list_of_packets"])
    delay_from_packets = df["arrival_time_ms"] - df["send_time_ms"]

    a = plot_cdf_multiple([average_delay, delay_from_packets], i, legend=["From calculated delay", "From packets"])
    #     plt.xlim(0,200)

# %%
# trace_name = l_rate[0]["trace"]
# print(trace_name)

# with open(trace_name, "r") as f:
#     d = json.load(f)

# df = pd.DataFrame(d["uplink"]["trace_pattern"])
# time = [0] + list(df["duration"].cumsum())
# capacities = [df["capacity"].iloc[0]] + list(df["capacity"])

# s = pd.Series(index=pd.to_datetime(time, unit="ms"), data=capacities)
# s.head(-10)

# %%
# s.resample("200ms").ffill()

# %% [markdown]
# ## Main code

# %%
pickle_path = "/home/dena/Documents/Gym_RTC/gym-example/rates_delay_loss.pickle"
l_rate = pd.read_pickle(pickle_path)

time_step = 200

# %%
l_rate[0].keys()
# Out:
# dict_keys(['trace', 'bandwidth_prediction', 'sending_rate', 'receiving_rate', 'delay', 'loss_ratio', 'log_prediction', 'reward'])

# %%
colors = iter(["dodgerblue", "teal", "indianred", "olive", "red", "green"])

# for i in range(len(l_rate)):
for i in ['./traces/WIRED_900kbps.json']:
    
    for metric in ["bandwidth_prediction", "receiving_rate", "sending_rate", "delay", "loss_ratio", "reward"]:
    
        #Define capacity
        trace_name = i[0]
        print(trace_name)

        with open('../traces/WIRED_900kbps.json', "r") as f:
            d = json.load(f)

        df = pd.DataFrame(d["uplink"]["trace_pattern"])
        time = [0] + list(df["duration"].cumsum())
        capacities = [df["capacity"].iloc[0]] + list(df["capacity"])    

        df_rate = pd.DataFrame(l_rate[i][metric], columns=[metric])
        
        t = np.arange(len(df_rate))*time_step
        df_rate["time"] = t
        df_rate.set_index("time", inplace=True)
        
        if metric in ["bandwidth_prediction", "sending_rate", "receiving_rate"]:

            plt.figure(figsize=(16,5))
            plt.title(metric, fontsize=16)
            plt.step(df_rate.index, df_rate[metric]/1000, label=f"{metric} [kbps]", color=next(colors))
            plt.step(time, capacities, lw=2, label="link bandwidth [kbps]", color="orange")
            plt.legend()
            plt.ylabel("kbps")
            plt.xlabel("ms")
            plt.grid()
#             plt.ylim(0,10000)
            
        else:
            plt.figure(figsize=(16,5))
            plt.title(metric, fontsize=16)
            plt.step(df_rate.index, df_rate[metric], label=f"{metric}", color=next(colors))
            plt.ylabel(metric)
            plt.xlabel("ms")
            plt.grid()
# Out:
# .
# .
# .
# .
# .
# .

# %%
# metric = "sending_rate"

# df_rate = pd.DataFrame(l_rate[i][metric], columns=[metric])
# df_rate = df_rate/1000
# df_rate

# %%
# (df_rate["sending_rate"] > pd.Series(capacities)).sum()

# %%
# metric = "reward"

# reward = l_rate[i][metric]
# plt.plot(reward)

# %% [markdown]
# ## Stable baselines implementation

# %%
pickle_path = "../rates_delay_loss_sb.pickle"
l_rate = pd.read_pickle(pickle_path)

time_step = 200

# %%
colors = iter(["dodgerblue", "teal", "indianred", "olive", "red", "green"])

for metric in ["bandwidth_prediction", "receiving_rate", "sending_rate", "delay", "loss_ratio", "reward"]:

    #Define capacity
    trace_name = l_rate["trace"]
    print(trace_name)
    trace_name = "../" + trace+

    with open(trace_name, "r") as f:
        d = json.load(f)

    df = pd.DataFrame(d["uplink"]["trace_pattern"])
    time = [0] + list(df["duration"].cumsum())
    capacities = [df["capacity"].iloc[0]] + list(df["capacity"])    

    df_rate = pd.DataFrame(l_rate[metric], columns=[metric])

    t = np.arange(len(df_rate))*time_step
    df_rate["time"] = t
    df_rate.set_index("time", inplace=True)

    if metric in ["bandwidth_prediction", "sending_rate", "receiving_rate"]:

        plt.figure(figsize=(16,5))
        plt.title(metric, fontsize=16)
        plt.step(df_rate.index, df_rate[metric]/1000, label=f"{metric} [kbps]", color=next(colors))
        plt.step(time, capacities, lw=2, label="link bandwidth [kbps]", color="orange")
        plt.legend()
        plt.ylabel("kbps")
        plt.xlabel("ms")
        plt.grid()
#             plt.ylim(0,10000)

    else:
        plt.figure(figsize=(16,5))
        plt.title(metric, fontsize=16)
        plt.step(df_rate.index, df_rate[metric], label=f"{metric}", color=next(colors))
        plt.ylabel(metric)
        plt.xlabel("ms")
        plt.grid()
# Out:
# ./traces/WIRED_900kbps.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_41254/4229615108.py in <module>
#       7     print(trace_name)
#       8
# ----> 9     with open(trace_name, "r") as f:
#      10         d = json.load(f)
#      11
#
# FileNotFoundError: [Errno 2] No such file or directory: './traces/WIRED_900kbps.json'

# %% [markdown]
# ## TODO: Figure out sending rate!!

# %%
df_packets = pd.DataFrame(l_rate[0]["list_of_packets"])
df_packets

# %%
dff = df_packets[df_packets.ssrc ==12648429].sort_values(by="sequence_number").sequence_number.diff()
dff

# %%
dff[dff != 1]

# %%
df_packets.loc[1617:1664]

# %%
interval2 = dff.arrival_time_ms.diff()[1::2]
interval2[interval2 > 60]

# %%
interval = dff.send_time_ms.diff()[1::2]
interval

# %%
interval[interval>60].index

# %%
df_packets[df_packets.sequence_number == 31]

# %%
dff.loc[[20,21,22,23,70,71]]

# %%
df_packets.loc[18:70]

# %%
pickle_path = "../output/rates_delay_loss_SAC_vec_env.pickle"
pickle_path = "../output/rates_delay_loss_SAC_4G_500kbps.pickle"
pickle_path = "../output/rates_delay_loss_SAC_WIRED_900kbps.pickle"
# pickle_path = "../output/rates_delay_loss_SAC_train_traces_one_by_one.pickle"
l_rate = pd.read_pickle(pickle_path)

# %%
l_rate.keys()
# Out:
# dict_keys(['./traces/WIRED_900kbps.json'])

# %%
len(l_rate['./traces/WIRED_900kbps.json'][0]["bandwidth_prediction"])
# Out:
# 289

# %%
plt.plot(l_rate['./traces/WIRED_900kbps.json'][0]["reward"])
